# %%
import numpy as np
import pandas as pd
import math

# %% [markdown]
# ### Functions and Classes

# %%
class index(object):
    def __init__(self, index_dec):
        self.dec = index_dec + 1
        self.bin = np.array([int(i) for i in str(bin(index_dec))[2:].zfill(n)])
        self.inmethod= []
        self.indegree = 0

# %%
def IsLeftSwap(latter, former):
    dif = latter.bin - former.bin
    dif = list(dif)
    if 1 in dif and -1 in dif:
        ip1 = dif.index(1)
        in1 = dif.index(-1)
        if ip1 == in1 - 1:
            dif.pop(ip1)
            dif.pop(ip1)
            if not (1 in dif or -1 in dif):
                return True
    return False

# %%
def IsAddOne(latter, former):
    dif = latter.bin - former.bin
    dif = list(dif)
    if 1 in dif:
        ip1 = dif.index(1)
        dif.pop(ip1)
        if not (1 in dif or -1 in dif):
            return True
    return False

# %%
def SortKey(a):
    return int(''.join([str(i) for i in a.inmethod]))

# %% [markdown]
# ### Generate Hasse Graph

# %%
n = 9
N = 2**n
A = int((6/math.pi)**0.5*2**n/n**1.5)

# %%
Nindex = [index(i) for i in range(N)]
res = [[Nindex[0]]]

# Generate Layers
for i in Nindex[1:]:
    tmp = []
    for j in range(len(res)):
        for k in res[-1-j]:
            if IsLeftSwap(i,k):
                tmp.append(1)
            elif IsAddOne(i,k):
                tmp.append(2)
        if tmp:
            if j == 0:
                res.append([i])
            else:
                res[-j].append(i)
            break
        else:
            i.trans = []

# Sort the Layers
for i in range(1, len(res)):
    for j in res[i]:
        for k in res[i-1]:
            if IsLeftSwap(j,k):
                j.inmethod.append(1)
                j.indegree += 1
            elif IsAddOne(j,k):
                j.inmethod.append(2)
                j.indegree += 1
            else:
                j.inmethod.append(9)
    res[i] = sorted(res[i], key=SortKey)

# %%
# Fill the Layers with None
A = len(res[int(len(res)/2)])

for i in range(len(res)):
    if len(res[i]) < A:
        if i < int(len(res)/2):
            res[i] = res[i] + [None]*(A-len(res[i]))
        else:
            res[i] = [None]*(A-len(res[i])) + res[i]

# %%
chains = [[] for i in range(A)]
for i in res:
    for j in range(A):
        if i[j]:
            chains[j].append(i[j].dec)

# %%
chains
# Out:
# [[1,
#   2,
#   3,
#   5,
#   9,
#   17,
#   33,
#   65,
#   129,
#   257,
#   258,
#   259,
#   261,
#   265,
#   273,
#   289,
#   321,
#   385,
#   386,
#   387,
#   389,
#   393,
#   401,
#   417,
#   449],
#  [4,
#   6,
#   10,
#   18,
#   34,
#   66,
#   130,
#   131,
#   133,
#   260,
#   262,
#   266,
#   274,
#   290,
#   322,
#   323,
#   325,
#   388,
#   390,
#   394,
#   402,
#   418,
#   450],
#  [7,
#   11,
#   19,
#   35,
#   67,
#   69,
#   132,
#   137,
#   145,
#   263,
#   267,
#   275,
#   291,
#   293,
#   324,
#   329,
#   337,
#   391,
#   395,
#   403,
#   419,
#   451,
#   453],
#  [8,
#   13,
#   21,
#   37,
#   68,
#   73,
#   134,
#   138,
#   161,
#   264,
#   269,
#   277,
#   292,
#   297,
#   326,
#   330,
#   353,
#   392,
#   397,
#   405,
#   421,
#   452],
#  [12,
#   20,
#   36,
#   41,
#   70,
#   81,
#   135,
#   146,
#   193,
#   268,
#   276,
#   281,
#   294,
#   305,
#   327,
#   338,
#   354,
#   396,
#   404,
#   420,
#   425,
#   457],
#  [14,
#   25,
#   38,
#   49,
#   74,
#   97,
#   139,
#   162,
#   194,
#   270,
#   278,
#   282,
#   298,
#   306,
#   331,
#   339,
#   355,
#   398,
#   409,
#   422,
#   454,
#   465],
#  [22,
#   26,
#   42,
#   71,
#   82,
#   136,
#   147,
#   163,
#   195,
#   271,
#   279,
#   295,
#   299,
#   328,
#   333,
#   341,
#   357,
#   406,
#   410,
#   433,
#   458,
#   481],
#  [15,
#   23,
#   39,
#   50,
#   75,
#   98,
#   141,
#   149,
#   165,
#   197,
#   272,
#   283,
#   296,
#   307,
#   332,
#   340,
#   356,
#   399,
#   407,
#   426,
#   455,
#   466],
#  [16,
#   27,
#   43,
#   72,
#   83,
#   140,
#   148,
#   164,
#   196,
#   201,
#   280,
#   285,
#   301,
#   309,
#   334,
#   345,
#   361,
#   400,
#   423,
#   434,
#   459,
#   482],
#  [24,
#   40,
#   51,
#   77,
#   99,
#   142,
#   153,
#   169,
#   198,
#   209,
#   284,
#   300,
#   308,
#   313,
#   342,
#   358,
#   369,
#   411,
#   427,
#   456,
#   467],
#  [29,
#   45,
#   76,
#   85,
#   101,
#   150,
#   166,
#   177,
#   202,
#   225,
#   286,
#   302,
#   310,
#   335,
#   346,
#   362,
#   408,
#   424,
#   435,
#   461,
#   483],
#  [28,
#   44,
#   53,
#   84,
#   100,
#   143,
#   154,
#   170,
#   199,
#   210,
#   226,
#   287,
#   303,
#   314,
#   343,
#   359,
#   370,
#   413,
#   429,
#   460,
#   469,
#   485],
#  [30,
#   52,
#   78,
#   89,
#   105,
#   151,
#   167,
#   178,
#   203,
#   211,
#   227,
#   288,
#   311,
#   336,
#   347,
#   363,
#   412,
#   428,
#   437,
#   468,
#   484],
#  [46,
#   57,
#   86,
#   102,
#   144,
#   155,
#   171,
#   200,
#   205,
#   213,
#   229,
#   304,
#   315,
#   344,
#   360,
#   371,
#   414,
#   436,
#   462,
#   473,
#   489],
#  [31,
#   54,
#   79,
#   90,
#   113,
#   152,
#   168,
#   179,
#   204,
#   212,
#   228,
#   233,
#   312,
#   317,
#   349,
#   365,
#   373,
#   430,
#   441,
#   470,
#   486,
#   497],
#  [47,
#   58,
#   87,
#   106,
#   114,
#   157,
#   173,
#   181,
#   206,
#   217,
#   230,
#   241,
#   316,
#   348,
#   364,
#   372,
#   415,
#   438,
#   463,
#   474,
#   490,
#   498],
#  [32,
#   55,
#   80,
#   103,
#   107,
#   156,
#   172,
#   180,
#   185,
#   214,
#   218,
#   234,
#   242,
#   318,
#   350,
#   366,
#   377,
#   431,
#   442,
#   471,
#   487,
#   491],
#  [48,
#   59,
#   91,
#   104,
#   115,
#   158,
#   174,
#   182,
#   207,
#   215,
#   231,
#   235,
#   243,
#   319,
#   351,
#   374,
#   416,
#   439,
#   464,
#   475,
#   488,
#   499],
#  [56,
#   88,
#   93,
#   109,
#   117,
#   159,
#   175,
#   186,
#   208,
#   219,
#   232,
#   237,
#   245,
#   320,
#   367,
#   378,
#   432,
#   443,
#   472,
#   477,
#   493,
#   501],
#  [61,
#   92,
#   108,
#   116,
#   121,
#   160,
#   183,
#   187,
#   216,
#   221,
#   236,
#   244,
#   249,
#   352,
#   375,
#   379,
#   440,
#   445,
#   476,
#   492,
#   500,
#   505],
#  [60,
#   62,
#   94,
#   110,
#   118,
#   122,
#   176,
#   184,
#   189,
#   220,
#   222,
#   238,
#   246,
#   250,
#   368,
#   376,
#   381,
#   444,
#   446,
#   478,
#   494,
#   502,
#   506],
#  [63,
#   95,
#   111,
#   119,
#   123,
#   125,
#   188,
#   190,
#   191,
#   223,
#   239,
#   247,
#   251,
#   253,
#   380,
#   382,
#   383,
#   447,
#   479,
#   495,
#   503,
#   507,
#   509],
#  [64,
#   96,
#   112,
#   120,
#   124,
#   126,
#   127,
#   128,
#   192,
#   224,
#   240,
#   248,
#   252,
#   254,
#   255,
#   256,
#   384,
#   448,
#   480,
#   496,
#   504,
#   508,
#   510,
#   511,
#   512]]

# %% [markdown]
# ### Test Hasse Graph

# %%
for i in range(len(res)):
    dif = len(res[i]) - len(res[-1-i])
    if not dif == 0:
        print(dif)

# %% [markdown]
# ### Save Hasse Chains

# %%
chains_df = pd.DataFrame(chains).T

# %%
chains_df.to_csv('Hasse_Chains_' + str(N) + '.csv')
